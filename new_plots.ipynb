# %%
from muon_analysis import *
import mplhep as hep
hep.style.use(hep.style.ATLAS)

bib_sk_file_0point2g = JetPlotter('june_29/lctuple_Output_REC_bib_kh_sk_0.2g.slcio.root')
nbib_sk_file_0point2g = JetPlotter('june_29/lctuple_Output_REC_nbib_kh_sk_0.2g.slcio.root')

bib_sk_file_1g = JetPlotter('aug_21/lctuple_Output_REC_bib_1point5tev_hsbib_100.root')
nbib_sk_file_1g= JetPlotter('aug_21/lctuple_Output_REC_nbib_1point5tev_hsbib_100.root')

bib_nosel= JetPlotter('aug_21/lctuple_Output_REC_bib_1point5tev_hsbib_100_regjet.root')

# %%
bib_sk_file_0point2g.num_jets_plotter('0 MeV', method='sk', a=0.2)
plt.savefig("/Users/khurriccan/Desktop/overleaf_plots/new_plots/sk_bib_num_jets_0point2g.png")
bib_sk_file_1g.num_jets_plotter('0 MeV', method='sk', a=1.0)
plt.savefig("/Users/khurriccan/Desktop/overleaf_plots/new_plots/sk_bib_num_jets_1g.png")

# %%
JetPlotter.histo2d(bib_nosel.pt_jet(), bib_nosel.theta_jet())
plt.savefig("/Users/khurriccan/Desktop/overleaf_plots/nosel_bib_2dhisto_pt_theta.png")
plt.show()

# %%
JetPlotter.overlayed2h(bib_sk_file_1g.invmass_lead_jets(), nbib_sk_file_1g.invmass_lead_jets(),"0 MeV", method ="sk", a=1.0)
plt.savefig("/Users/khurriccan/Desktop/overleaf_plots/new_plots/sk_invmas_lead_jets_plot_1g_1point5tev.png")
