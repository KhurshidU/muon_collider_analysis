# %%
from muon_analysis import *
import mplhep as hep
hep.style.use(hep.style.ATLAS)

# %%
bib_File= JetPlotter('june_29/lctuple_Output_REC_bib_kh_nsk.slcio.root')
nbib_File = JetPlotter('june_29/lctuple_Output_REC_nbib_kh_nsk.slcio.root')
#plt.style.use(matplotx.styles.github['dark'])

# %%
bib_File.invm2j_plotter()
nbib_File.invm2j_plotter()
#bib_File.saver()

# we need a way of creating a folder for a common plots 
plt.savefig(nbib_File.file_name()+"invmass_all_jets"+nbib_File.exten)
plt.show()

bib_File.maxj_p_plotter()
nbib_File.maxj_p_plotter()
#bib_File.saver()
plt.savefig(nbib_File.file_name()+"max_j_p"+nbib_File.exten)
plt.show()

#type(bib_File.invm2j_plotter())

# %%
JetPlotter.overlayed2h(bib_File.invmass_lead_jets(), nbib_File.invmass_lead_jets())
plt.savefig("/Users/khurriccan/Desktop/new_st_invmas_lead_jets_plot.png")
plt.show() 
JetPlotter.overlayed2h(bib_File.maxj_p(), nbib_File.maxj_p())
plt.savefig("/Users/khurriccan/Desktop/new_st_max_p_jet_plot.png")
plt.show()

# %%
JetPlotter.histo2d(nbib_File.pt_jet(), nbib_File.theta_jet())
plt.savefig("/Users/khurriccan/Desktop/nbib_2dhisto_pt_theta.png")
plt.show() 
JetPlotter.histo2d(bib_File.pt_jet(), bib_File.theta_jet())
plt.savefig("/Users/khurriccan/Desktop/bib_2dhisto_pt_theta.png")
plt.show()
